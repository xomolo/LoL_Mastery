# %%
from backend import check_champs

# %%
check_champs(15, 'token')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>champImage</th>
#       <th>championLevel</th>
#       <th>tokensEarned</th>
#       <th>chestGranted</th>
#       <th>championPoints</th>
#       <th>lastPlayTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Garen</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Garen.png" width="60"></td>
#       <td>6</td>
#       <td>2</td>
#       <td>False</td>
#       <td>34822</td>
#       <td>2023-12-19 12:59:16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Blitzcrank</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Blitzcrank.png" width="60"></td>
#       <td>6</td>
#       <td>1</td>
#       <td>False</td>
#       <td>50505</td>
#       <td>2024-03-06 22:57:05</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
check_champs(15, 'max')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>champImage</th>
#       <th>championLevel</th>
#       <th>tokensEarned</th>
#       <th>chestGranted</th>
#       <th>championPoints</th>
#       <th>lastPlayTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Renekton</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Renekton.png" width="60"></td>
#       <td>7</td>
#       <td>0</td>
#       <td>False</td>
#       <td>195674</td>
#       <td>2023-09-11 01:05:44</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Vayne</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Vayne.png" width="60"></td>
#       <td>7</td>
#       <td>0</td>
#       <td>False</td>
#       <td>194550</td>
#       <td>2024-03-03 11:00:19</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
check_champs(15, 'level')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>champImage</th>
#       <th>championLevel</th>
#       <th>tokensEarned</th>
#       <th>chestGranted</th>
#       <th>championPointsUntilNextLevel</th>
#       <th>lastPlayTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Annie</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Annie.png" width="60"></td>
#       <td>4</td>
#       <td>0</td>
#       <td>False</td>
#       <td>140</td>
#       <td>2023-09-08 00:04:54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Xayah</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Xayah.png" width="60"></td>
#       <td>4</td>
#       <td>0</td>
#       <td>False</td>
#       <td>417</td>
#       <td>2024-03-07 23:55:34</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
check_champs(15, 'chest')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>champImage</th>
#       <th>championLevel</th>
#       <th>tokensEarned</th>
#       <th>chestGranted</th>
#       <th>championPoints</th>
#       <th>lastPlayTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Renekton</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Renekton.png" width="60"></td>
#       <td>7</td>
#       <td>0</td>
#       <td>False</td>
#       <td>195674</td>
#       <td>2023-09-11 01:05:44</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Vayne</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.5.1/img/champion/Vayne.png" width="60"></td>
#       <td>7</td>
#       <td>0</td>
#       <td>False</td>
#       <td>194550</td>
#       <td>2024-03-03 11:00:19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jinx</td>
# ...
