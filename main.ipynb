# %%
from backend import check_champs

# %%
check_champs(15, 'token')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>champImage</th>
#       <th>championLevel</th>
#       <th>tokensEarned</th>
#       <th>chestGranted</th>
#       <th>championPoints</th>
#       <th>lastPlayTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Garen</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Garen.png" width="60"></td>
#       <td>6</td>
#       <td>2</td>
#       <td>False</td>
#       <td>34822</td>
#       <td>2023-12-19 12:59:16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Nunu y Willump</td>
#       <td><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nunu.png" width="60"></td>
#       <td>6</td>
#       <td>1</td>
#       <td>True</td>
#       <td>29537</td>
#       <td>2024-02-29 00:45:13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Senna</td>
# ...
